# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('/home/minwookje/code/python/crawling/chromedriver')
driver.implicitly_wait(3)

# %%
driver.get('https://coms.doc.state.mn.us/PublicViewer/Fugitive/')

# %%
from bs4 import BeautifulSoup

div_elems =

# %%
div_elems
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f5fc08606440c2560749fe4adda74b2b", element="0.07839377930132785-1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f5fc08606440c2560749fe4adda74b2b", element="0.07839377930132785-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f5fc08606440c2560749fe4adda74b2b", element="0.07839377930132785-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f5fc08606440c2560749fe4adda74b2b", element="0.07839377930132785-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f5fc08606440c2560749fe4adda74b2b", element="0.07839377930132785-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f5fc08606440c2560749fe4adda74b2b", element="0.07839377930132785-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f5fc08606440c2560749fe4adda74b2b", element="0.07839377930132785-7")>,
# ...

# %%
elem = driver.find_elements_by_tag_name("body")

pagedowns = 1
while pagedowns <20:
    img = driver.find_elements_by_class_name("fugitiveImageInner")
    for i in img:
        alt
